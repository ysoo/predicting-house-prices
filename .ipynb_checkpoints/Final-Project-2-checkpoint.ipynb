# %% [markdown]
# ### CS/ECE/ISyE 524  - Introduction to Optimization - Fall 2018

# %% [markdown]
# # Using Regression to Predict Housing Prices

# %% [markdown]
# #### Yi Xian Soo (ysoo@wisc.edu) , Taijing Chen (tchen284@wisc.edu)

# %% [markdown]
# ### Table of Contents
# 1. [Introduction](#1.-Introdiction)
# 2. [Mathematical Model](#2.-Mathematical-model)
# 3. [Solution](#3.-Solution)
# 4. [Results and Discussion](#4.-Results-and-discussion)
# 5. [Conclusion](#5.-Conclusion)

# %% [markdown]
# ## 1. Introduction ##

# %% [markdown]
# A house is one of the biggest puchase that an average person will make. Predicting housing prices is important. From the persepctive of the salers, a good prediction can help them set the sale price competitive in the marktet; From the perspective of the buyers, estimation of saling price can help them maximize living experience with a reasonable budget. However, housing prices are determined by a wide variety of factors that are difficult to quantify and aren't at all obvious to the casual observer. In this project, we will attempt to predict housing prices located in Ames, Iowa. This dataset contains 1460 training data and 79 training labels.  To make a prediction, we need to answer two questions: (1) What labels are actually meaningfully-related to the housing prices; (2) If a label is related to the housing price, how should we use it to predict the housing prices. It is impossible for a person to utilize such information and make a solid prediction based on heuristic assumption or intuition. As a result, we will let optimization to help us. In this project, we are going to show how to use regression analysis with regularization to learn from the data so as to predict housing prices. We will start from explaining the mathmatical models behind in part 2. After it, in part 3 we will preprocess the data and plot the correlation matrix between labels and housing prices to identify meaningful labels. Then, we will solve the optimization problem by combining least square cost and the huber loss with three common regularizations. The discussion and comparisons of models will also be presented. In part 4, we will answer the bigger picture, and discuss about limitation and possible improvement of this project.
#
#
# This dataset is contributed by Dean De Cock. He was a graduate student at the Truman State University and he was looking for a data set that would allow the students in his statistic class to experiment their knowledge on. He required a data set that has a reasonably large number of variables and observations, hence, on his sabbatical leave, he contacted the Ames City Assessor's Office to be given access to city's housing data.

# %% [markdown]
# ## 2. Mathematical models
#
# In order to predict future housing prices based on the given data, we're going to apply different regression approaches to find the best linear model that determines the relationship between parameters and target housing prices. In this project, we will use $L_{\infty}$ regularization, $L_1$ regularization, $L_2$ regularization and combinations of them to avoid overfitting, and utilize the huber loss to avoid the outlier, so that we can get an accurate, robust and fruitful model on housing price prediction.

# %% [markdown]
# ### 2.1 Data Prepocessing
# The Ames Housing dataset contains 2919 sets of data with 79 labels and their corresponding housing prices. For the purposes of this project, we have split the data into 2 sets, the training set and the testing set. The training set contains 1460 data points whereas the testing set contains 1459 data points. In the given data set, we need to deal with two different types of data: numerical variables and discrete variables. Before building the model, we need to preprocess the data for two purposes: (1) convert all data into numerical ones; (2) reduce the number of labels we care about.
#
# #### 2.1.1 Numerical (continuous) variables
# The followings are the labels containing numerical values. We can just use them without preprocessing.
#
# |Label Name |LabelID|Description
# |-----------|-------|--------------------------------------------------------------
# |MSSubClass |1      |Identifies the type of dwelling involved in the sale (in numerical form already)
# |LotFrontage|3      |Linear feet of street connected to the property
# |LotArea    |4      |Lot size in square feet
# |YearBuilt  |19     |Original construction date
# |YearRemodAdd|20    |Remodel date
# |MasVnrArea |26     |Masonry veneer area in square feet
# |BsmtFinSF1 |34     |Type 1 finished square feet
# |BsmtFinSF2 |36     |Type 2 finished square feet
# |BsmtUnfSF  |37     |Unfinished square feet of basement area
# |TotalBsmtSF|38     |Total square feet of basement area
# |1stFlrSF   |43     |First Floor square feet
# |2ndFlrSF   |44     |Second floor square feet
# |LowQualFinSF|45    |Low quality finished square feet (all floors)
# |GrLivArea  |46     |Above grade (ground) living area square feet
# |BsmtFullBath|47    |Basement full bathrooms
# |BsmtHalfBath|48    |Basement half bathrooms
# |FullBath   |49     |Full bathrooms above grade
# |HalfBath   |50     |Half baths above grade
# |Bedroom    |51     |Bedrooms above grade (does NOT include basement bedrooms)
# |Kitchen    |52     |Kitchens above grade
# |TotRmsAbvGrd|54    |Total rooms above grade (does not include bathrooms)
# |Fireplaces |56     |Number of fireplaces
# |GarageYrBlt|59     |Year garage was built
# |GarageCars |61     |Size of garage in car capacity
# |GarageArea |62     |Size of garage in square feet
# |WoodDeckSF |66     |Wood deck area in square feet
# |OpenPorchSF|67     |Open porch area in square feet
# |EnclosedPorch|68   |Enclosed porch area in square feet
# |3SsnPorch  |69     |Three season porch area in square feet
# |ScreenPorch|70     |Screen porch area in square feet
# |PoolArea   |71     |Pool area in square feet
# |MiscVal    |75     |$Value of miscellaneous feature
# |MoSold     |76     |Month Sold (MM)
# |YrSold     |77     |Year Sold (YYYY)
#
#
# #### 2.1.2 Discrete variables
# In the dataset, there are some nonnumerical data. In order to use solver to help us solve the problem, we need to change the discrete variables. There are two different discrete data in the Ames Housing dataset. **The first type of discrete variables, despite being discontinuous, only varies in the level of degrees.** For example, consider the following feature of "LotShape", which indicates the "general shape of the property":
#
# |Label |Description |
# |-----|------------|
# |REG  |Regular     |
# |IR1  |Slightly irregular|
# |IR2  |Moderately irregular|
# |IR3  |Irregular   |
#
# For this types of variables, we will label them by increasing positive integers based on the level of degrees. Specifically,in the example of "LotShape", we will set the features to be:
#
# |Label |Value |
# |-----|------------|
# |REG  |1     |
# |IR1  |2     |
# |IR2  |3     |
# |IR3  |4     |
#
# This technique will be applied to the following labels:
#
# |Label Name |LabelID|Description
# |-----------|-------|-----------------------------------------------------------------
# |LotShape   |7      |General shape of property
# |LandContour|8      |Flatness of the property
# |Utilities  |9      |Type of utilities available
# |LotConfig  |10     |Lot Configuration
# |LandSlope  |11     |Slope of the property
# |Condition1 |13     |Proximity to various conditions
# |Condition2 |14     |Proximity to various conditions (if more than one is present)
# |BlgType    |15     |Type of dwelling
# |HouseStyle |16     |Style of dwelling
# |ExterQual  |27     |Evaluates the quality of the material on the exterior
# |ExterCond  |28     |Evaluates the present condition of the material on the exterior
# |BsmtQual   |30     |Evaluates the height of the basement
# |BsmtCond   |31     |Evaluates the general condition of the basement
# |BsmtExposure|32    |Refers to walkout or garden level walls
# |BsmtFinType1|33    |Rating of basement finished area
# |BsmtFinType2|35    |Rating of basement finished area (if multiple types)
# |HeatingQC  |40     |Heating quality and condition
# |CentralAir |41     |Central air conditioning
# |KitchenQual|53     |Kitchen quality
# |Functional |55     |Home Functionality
# |FireplaceQu|57     |Fireplace quality
# |GarageType |58     |Garage location
# |GarageFinish|60    |Interior finish of the garage
# |GarageQual |63     |Garage quality
# |GarageCond |64     |Garage condition
# |PavedDrive |65     |Paved driveway
# |PoolQC     |72     |Pool quality
# |Fence      |73     |Fence quality
# |SaleType   |78     |Type of sale
# |SaleCondition| 79  |Condition of Sale
#
#
# **The second type of discrete variables has no relation of degrees.** The values of these variables are different names of features corresponding to a given lable. For instance, in the example of "Alley", i.e., the "type of alley access to property", we have:
#
# |Features |Description  |
# |-----|-------------|
# |Grvl |Gravel       |
# |Pav  |Paved        |
# |NA   |No alley access|
#
# Since these are distinct features of a given label, it is no longer safe to lable them by increasing integers. To make these discrete variables linear, we need to change each of them into binary variables $1$ and $0$. $1$ means that the given label has this feature, and $0$ means the opposite. If a given lable $l$ has $m$ features, after the transformation, we will have $2^m$ new labels. In the other words, here's the new labels we have:
#
# |Labels |Description  |
# |-----|-------------|
# |Grvl |has gravel (1) or not (0)
# |Pav  |paved (1) or not (0)
# |NA   |no alley access (1) or not (0)
#
# This technique will be applied to the following data:
#
# |Label Name |LabelID|Description
# |-----------|-------|-------------------------------------------------------------------
# |MSZoning   |2      |Identifies the general zoning classification of the sale
# |Street     |5      |Type of road access to property
# |Alley      |6      |Type of alley access to property
# |Neighborhood|12    |Physical locations within Ames city limits
# |RoofStyle  |21     |Type of roof
# |RoofMatl   |22     |Roof material
# |Exterior1st|23     |Exterior covering on house
# |Exterior2nd|24     |Exterior covering on house (if more than one material)
# |MasVnrType |25     |Masonry veneer type
# |Foundation |29     |Type of foundation
# |Heating    |39     |Type of heating
# |Electrical |42     |Electrical system
# |MiscFeature|74     |Miscellaneous feature not covered in other categories

# %% [markdown]
# #### 2.1.3 Reducing labels
#
# After transforming all labels into numerical ones, we are faced with a much larger dataset. Such large data might slow down the model and introduce unneccessary noise into the model. One way to solve this problem is to get rid of poorly related labels. Here, we will use the pearson correlation coefficient r defined by the corvariance of two variables divided by the product of their standard deviation. The mathematic expression is given below [1]:
#
# $$
# r = \frac{\sum_{i=1}^{n}(x_i-\bar x)(y_i-\bar y)}{\sqrt{\sum_{i=1}^n(x_i-\bar x)^2}\sqrt{\sum_{i=1}^n(y_i-\bar y)^2}}
# $$
#
# This correlation coefficient measures the linear correlation of two variables x and y, ranging from -1 to 1. In this project, if the correlation between a label and the housing price is less than 0.3, ie, $-0.3 < r < 0.3$, we will drop the label.
#
# [1]: https://en.wikipedia.org/wiki/Pearson_correlation_coefficient

# %% [markdown]
# ### 2.2 A General Discussion of Linear Regression
#
# Define
#
# $m :=$ number of labels
#
# $n :=$ number of datasets
#
# To predict the future housing prices, we can assign different weights to the labels. By doing so, the problem will be modeled by a linear function looks like this:
# $$\hat{y}=w^{\intercal}x, w \in \Re^{m\times1}, x \in \Re^{n\times 1}$$
# To find the model fits the data, we would like to use different approaches to find a linear function that gives a prediction as close as to the actual value. This is equivalent to solve the following model:
# $$
# \begin{aligned}
# \min_{w \in \Re^{m \times 1}} \quad & \sum_{i=1}^n error(y,\hat{y}) \\
# s.t. \quad & \hat{y}=w^{\intercal}x
# \end{aligned}
# $$
#
# We will model this problem using affine functions. So instead using the data naively, we will append one column of 1's to the dataset and add one more weight variable to $w$. Let
#
# $w :=$ weights of each label $\in\Re^{m+1}$;
#
# $A :=$ all datasets $\in\Re^{n\times (m+1)}$, where $A_{i(m+1)} = 1 \quad \forall i = 1...n$;
#
# Using least square as the cost function, We have the following optimization model:
#
# $$
# \begin{aligned}
# \min_{w} \quad & \lVert y-Aw \rVert^2 \\
# \end{aligned}
# $$
#
# However, in reality, we need to deal with outfitting and outliers. A reliable model should be able to cope with different situations and remain robust. An possible solution is using regularization. In the following paragraphs, we will use $L_2$ cost model as an example and discuss about how to make the model robust.

# %% [markdown]
# ### 2.3 Overfitting
# Even though having various features sounds good for the sake of model training as they provides the models more options to look for, too many features can lead to negative outcomes when it goes to extreme. After knowing the details of the data, the model will sometimes overly pick up the noise and random fluctuations, which may not apply to new data, and generate a complicated function to fit the data. The complicated function can not only slow down the performance of the model, but also results in great error when predicting by new data. Since the problem is caused by the overly-complicated function, a possible solution to counteract this negative impact would be just simplifying the model. To do so, a common approach is to limit the weights $w$ in our model by regularization.
# Again, Let
#
#
# $w :=$ weights of each label $\in\Re^{m+1}$;
#
# $A :=$ all datasets $\in\Re^{n\times (m+1)}$, where $A_{i(m+1)} = 1 \quad \forall i = 1...n$;
#
# $x_i := i^{th}$ row in A $\in\Re^{1\times (m+1)}$.
#
# Here are three common cost applied in regulariation we have:
#
# **$L_{\infty}$ cost**(Minimax/LP), which **equalizes** the solution
# $$
# \begin{aligned}
# \min_{w} \quad & \max_{w} \lVert y_i-x_iw \rVert \\
# \end{aligned}
# $$
# standard LP form:
# $$
# \begin{aligned}
# \min_{w,t} \quad & t \\
# s.t.       \quad & t \geq y-x_iw \\
#            \quad & t \geq x_1w-y
# \end{aligned}
# \quad\implies\quad
# \begin{aligned}
# \min_{w,t} \quad & t \\
# s.t.       \quad & -t+x_iw \leq y \\
#            \quad & -t-x_iw \leq -y
# \end{aligned}
# $$
#
# **$L_1$ cost**(Epigraph trick/LP), which **spartifies** the solution
# $$
# \begin{aligned}
# \min_{w} \quad & \sum_{i=1}^n  \lVert y_i-x_iw \rVert \\
# \end{aligned}
# $$
# standard LP form:
# $$
# \begin{aligned}
# \min_{w,t} \quad & \sum_{i=1}^n  t_i \\
# s.t.       \quad & t_i \geq y-x_iw \\
#            \quad & t_i \geq x_iw-y
# \end{aligned}
# \quad\implies\quad
# \begin{aligned}
# \min_{w,t} \quad & \sum_{i=1}^n  t_i \\
# s.t.       \quad & -t_i+x_iw \leq y \\
#            \quad & -t_i-x_iw \leq -y
# \end{aligned}
# $$
#
# **$L_2$ cost** (Least squares/QP), which **smooths** the solution
# $$
# \begin{aligned}
# \min_{w} \quad & \lVert y-Aw \rVert^2 \\
# \end{aligned}
# $$
#
# In this chapter, we will discuss these three regularization approaches dealing with overfitting in regression.

# %% [markdown]
# #### 2.3.1 L2 Regularization (Ridge Regression)
# To make the model simple, we would prefer simple weight vector $w$. One way to achieve this goal is to constrain the values of $w$ by regularization. One common approach, Ridge regression, utilizes the features of L2 regularization to simplify the model via smoothing the values of $w$. It is in the following form:
#
# $$
# \begin{aligned}
# \min_{w} \quad &  \lVert y-Aw \rVert^2 + \lambda\lVert w\rVert^2 \\
# \end{aligned}
# $$
#
# Sometimes, it is also written in a slightly different form:
# $$
# \begin{aligned}
# \min_{w}   \quad & \lVert y-Aw\rVert^2 \\
# \text{s.t} \quad & \lVert w\rVert^2 \leq t
# \end{aligned}
# $$
#
# By plotting the feasible region and the objective function, we can observe some features of this type of regression.

# %%
using PyPlot
using PyCall
@pyimport matplotlib.patches as patch

cfig = figure()
ax = cfig[:add_subplot](1,1,1)
ax[:set_aspect]("equal")
c = patch.Circle([0,0],1,linewidth=.5,zorder=0)
e1 = patch.Ellipse((2.1, 2), 4, 2, 30, fill=false)
e2 = patch.Ellipse((2.1, 2), 3, 1.5, 30, fill=false)
e3 = patch.Ellipse((2.1, 2), 2, 1, 30, fill=false)
ax[:add_artist](c)
ax[:add_artist](e1)
ax[:add_artist](e2)
ax[:add_artist](e3)
plot(0.56, 0.83, "r.")
plot(2.1, 2, "m.")
xlim(-2, 5)
ylim(-2, 5)
title("L2 (Ridge) Regression")
;
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# The blue region is the feasible region, and the ellipse-shaped lines are the objective contours. The ridge estimate is given by the point at which the ellipse and the circle touch. As we can see, the optimal point occurs on the edge of the circle. Since there is no corner point for the circle, the weight vector $w$ we get would unlikely contain entry of value 0. Therefore, this regularization approach tend to be more useful when most labels are useful.This is the main difference from the next model we are goint to discuss about: the L1 (Lasso) Regression.

# %% [markdown]
# #### 2.3.2 L1 Regularization (Lasso Regression)
# As mentioned previously, if we use the L2 (Ridge) regression, the weight vector $w$ is unlikely to go zero. However, in the given dataset, there are 79 labels. Not all of them have effect on the housing price. In these cases, to assign zero weight to these label may be a better option. One applicable method is that before regression, we can plot the correlation matrix between labels and the housing prices, and eliminate the labels if their correlation is too low. However, this requires us to manually discard the labels that we do not want to use.
# A better method that automate this process is the Lasso regression which incoperate L1 regularization:
#
# $$
# \begin{aligned}
# \min_{w} \quad & \lVert y-Aw\rVert^2 + \lambda\sum_{i=1}^n\lVert w_i\rVert \\
# \end{aligned}
# $$
#
# It can be written in this form as well:
#
# $$
# \begin{aligned}
# \min_{w} \quad & \lVert y-Aw \rVert^2 \\
# \text{s.t.} \quad & \sum_{i=1}^n\lVert w_i\rVert \leq t
# \end{aligned}
# $$
#
# Because this approach uses the L1 regularization, as discussed previously, the values of $w$ obtained will tend to be sparse. As a result, this regularizaiton simplify $w$ by generating as many zero entries as possible. By plotting the feasible region and the objective function, we can observe some other features of L1 regularization as well:

# %%
using PyPlot
using PyCall
@pyimport matplotlib.patches as patch

cfig = figure()
ax = cfig[:add_subplot](1,1,1)
ax[:set_aspect]("equal")
r = patch.Polygon([(0,1), (1,0), (0,-1), (-1,0)])
e1 = patch.Ellipse((1.4, 2.45), 4, 2, 45, fill=false)
e2 = patch.Ellipse((1.4, 2.45), 3, 1.5, 45, fill=false)
e3 = patch.Ellipse((1.4, 2.45), 2, 1, 45, fill=false)
ax[:add_artist](r)
ax[:add_artist](e1)
ax[:add_artist](e2)
ax[:add_artist](e3)
plot(0, 1, "r.")
plot(1.4, 2.45, "m.")
xlim(-2, 5)
ylim(-2, 5)
title("L2 (Ridge) Regression")
;
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Again, the blue region is the feasible region, and the ellipse-shaped lines are the objective contours. Unlike the graph for L2 regularization, the optimal points always occur at the corner of the feasible region, which means that the entries in weight vector $w$ can go to zero. Therefore, the L2 regularization can eliminate useless variables. Compared with L1 regularization, tt is more powerful when there're lots of useless variables.

# %% [markdown]
# #### 2.3.3 Combination of L1 Regularization & L2 Regularization
# Because both L1 regularization & L2 regularization have their strengths and weaknesses, we can get a better model if we conbine them:
#
# $$
# \begin{aligned}
# \min_{w} \quad &  \lVert y-Aw\rVert^2 + \lambda\lVert w\rVert^2 + \mu\sum_{i=1}^n\lVert w_i\rVert \\
# \end{aligned} \\
# \lambda\lVert w\rVert^2 \implies \quad \text{smooth } w \\
# \sum_{i=1}^n\lVert w_i\rVert \implies \quad \text{sparsify } w
# $$

# %% [markdown]
# ### 2.4 Outliers
#
# #### 2.4.1 Robust Regresssion using Huber Loss
# Since there are 1460 sets of data, this datasets may contains much noise. Ideally, to clean the data, we can plot the data and remove the outliers manually. However, due to large number of data and labels, it is not realistic to do so. To make the model robust, we will apply the Huber Loss to our model so that the outliers can be excluded automatically. Here is the formula fro the Huber Loss:
#
# $$
# \begin{aligned}
# \Phi(x) &=
#     \begin{cases}
#      x^2    &\text{if} -M \leq x \leq M \\
#      2M\lvert x \rvert -M^2 &\text{otherwise}
#     \end{cases} \\
#     &\text{,where M determines where to transit from linear to quadratic}
# \end{aligned}
# $$
#
# To make such loss function appliable to the solver, we will use the following convex QP form instead:
#
# $$
# \begin{aligned}
# \Phi(x) =
#     \begin{cases}
#     \min_{v,w}  &w^2+2Mv \\
#     \text{s.t.} &\lvert x \rvert \leq w+v \\
#                 &v \geq 0 \\
#                 &w \leq M
#     \end{cases}
# \end{aligned}
# $$
#
# The objective function of regression using the Huber Loss will be:
#
# $$
# \sum_{i=1}^{n} \Phi(y_i-ax_i)
# $$
#
# #### 2.4.2 Huber loss and regularizations
#
# Here are the models we will get after combining the Huber Loss and different regularizations. <br/>
#
# **Ridge Regression + Huber Loss**:
# $$
# \begin{aligned}
#     \min_{w} \quad &  \sum_{i=1}^{n} \Phi(y_i-x_iw) + \lambda\lVert w\rVert^2 \\
# \end{aligned}
# $$
#
# **Lasso Regression + Huber Loss**:
# $$
# \begin{aligned}
#     \min_{w} \quad & \sum_{i=1}^{n} \Phi(y_i-x_iw) + \lambda\sum_{i=1}^n\lVert w_i\rVert \\
# \end{aligned}
# $$
#
# **L1 + L2 + Huber Loss**:
# $$
# \begin{aligned}
# \min_{w} \quad &  \sum_{i=1}^{n} \Phi(y_i-x_iw) + \lambda\lVert w\rVert^2 + \mu\sum_{i=1}^n\lVert w_i\rVert \\
# \end{aligned}
# $$

# %% [markdown]
# ## 3. Solution and Results ##

# %% [markdown]
# ### 3.1 Data Preprocessing

# %% [markdown]
# ##### Encode Type a2 discrete variables (discrete but not absolutely catogorical)
#
# The function encode transforms discrete variables with variation in degree into continuous variable. The function encode was run on the training data ("train.csv") and the testing data ("test.csv") to obtain new data.

# %%
using JuMP, NamedArrays
data = readcsv("test.csv");
(m, n) = size(data);

function encode(array, name)
    dictionary = Dict()
    l = size(array)
    for j = 1: l[1]
         dictionary[array[j]] = j
    end
    
    toBeEncoded = data[2:m, name]
    
    for i = 1:m - 1
        curr = toBeEncoded[i]
        temp = get(dictionary, curr, 0)
        toBeEncoded[i] = temp
    end
    
    data[2:m, name] = toBeEncoded
end

encode(["Reg", "IR1", "IR2", "IR3"], 8);  # LotShape
encode(["Lvl", "Bnk", "HLS", "Low" ], 9);  # LandContour
encode(["AllPub", "NoSewr", "NoSeWa", "ELO"], 10); # Utilities
encode(["Inside", "Corner", "CulDSac", "FR2", "FR3"], 11) # Lot Configuration
encode(["Gtl", "Mod", "Sev"], 12); # LandSlope
encode(["Artery", "Feedr", "Norm", "RRNn", "RRAn", "PosN", "PosA", "RRNe", "RRAe"], 14) # Condition 1
encode(["Artery", "Feedr", "Norm", "RRNn", "RRAn", "PosN", "PosA", "RRNe", "RRAe"], 15) # Condition 2
encode(["1Fam", "2fmCon", "Duplex", "TwnhsE", "Twnhs"], 16); # BldgType
encode(["1Story", "1.5Fin", "1.5Unf","2Story","2.5Fin", "2.5Unf", "SFoyer", "SLvl"], 17) #HouseStyle
encode(["Po", "Fa", "TA", "Gd", "Ex"], 28) # ExterQual
encode(["Po", "Fa", "TA", "Gd", "Ex"], 29) # ExterCond
encode(["Po", "Fa", "TA", "Gd", "Ex"], 31) # BsmtQual
encode(["Po", "Fa", "TA", "Gd", "Ex"], 32) # BsmtCond
encode(["No", "Mn", "Av", "Gd"], 33) # BsmtExposure
encode(["Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"], 34) # BsmtFinType1
encode(["Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"], 36) # BsmtFinType2
encode(["Po", "Fa", "TA", "Gd", "Ex"], 41) # HeatingQC
encode(["N", "Y"], 42) # Central Air
encode(["Po", "Fa", "TA", "Gd", "Ex"], 54) # KitchenQual
encode(["Sal", "Sev", "Maj2", "Maj1", "Mod", "Min2", "Min1", "Typ"], 56) # Functional
encode(["Po", "Fa", "TA", "Gd", "Ex"], 58) # FireplaceQuality
encode(["Detchd", "CarPort", "BuiltIn", "Basment", "Attchd", "2Types"], 59) # GarageType
encode(["Unf", "RFn", "Fin"], 61) # GarageFinish
encode(["Po", "Fa", "TA", "Gd", "Ex"], 64) # GarageQuality
encode(["Po", "Fa", "TA", "Gd", "Ex"], 65) # GarageCond
encode(["N", "P", "Y"], 66) # PavedDrive
encode(["Fa", "TA", "Gd", "Ex"], 73) # PoolQC
encode(["MnWw", "GdWo", "MnPrv", "GdPrv"], 74) # Fence
encode(["WD", "CWD", "VWD", "New", "COD", "Con", "ConLw", "ConLI", "ConLD", "Oth"], 79) # SaleType
encode(["Normal", "Abnorml", "AdjLand", "Alloca", "Family", "Partial"], 80) # SaleCondition

writecsv("test-clean.csv", data)

# %% [markdown]
# ##### Encode Type a3 discrete variables (absolutely categorical)
#
# This block of code uses pandas' get_dummies function to transform absolutely categorical data into binary data within different columns. The code was ran on the testing data and the training data.
#
# The following block code replaces missing values with 0.

# %%
using JuMP, PyCall
@pyimport pandas as pd
train = pd.read_csv("test-clean.csv")
cols = ("MSZoning", "Street", "Alley", "Neighborhood", "RoofStyle", "RoofMatl", 
    "Exterior1st", "Exterior2nd", "MasVnrType", "Foundation", "Heating", "Electrical", "MiscFeature")

for c in cols
    temp = pd.get_dummies(train[c])
    train = pd.concat([train, temp], axis=1)
    train = train[:drop](columns=c)
end

train[:to_csv]("test-clean.csv")

# %%
using JuMP, PyCall
@pyimport pandas as pd
train = pd.read_csv("test-clean.csv")

train = train[:fillna](value = 0)

train[:to_csv]("test-clean.csv")

# %% [markdown]
# ##### Reducing variables

# %%
using JuMP, PyCall, PyPlot
@pyimport pandas as pd
@pyimport seaborn as sns
train = pd.read_csv("train-clean.csv")
train = train[:drop](columns="Id")
corrmat = train[:corr]();
salePrice = corrmat["SalePrice"]

index = 1
li = corrmat[:columns][:values]

for i in salePrice
    if abs(i) < 0.3
        train = train[:drop](columns = li[index])
    end
    index = index + 1
end

corrmat = train[:corr]();
plt[:figure](figsize=(12,10))
sns.heatmap(corrmat, vmax=0.9)
title("Heatmap of correlation matrix between variables")

train[:to_csv]("test-clean.csv")
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x1000 with 2 Axes>)
# PyObject Text(0.5,1,'Heatmap of correlation matrix between variables')

# %% [markdown]
# #### Importing training data

# %%
using JuMP, NamedArrays
raw_data = readcsv("train-clean.csv");
(M, N) = size(raw_data);

n_labels = 2:N  
n_ids = 2:M 

raw_data[n_ids, n_labels]

ids = raw_data[n_ids, 1][:]   
labels = raw_data[1, n_labels][:]
labels = vcat(labels, "Constant")

A = convert(Array{Float64,2}, raw_data[n_ids, n_labels])
B = ones(M-1)
data = hcat(A, B);

raw_prices = readcsv("train-sale-prices.csv")
prices = convert(Array{Float64}, raw_prices[n_ids]);

# %% [markdown]
# ##### Importing testing data

# %%
# Making the test data set
# Need to create a named array with the test set
using JuMP, NamedArrays

raw_test = readcsv("test-clean.csv");
(M_test, N_test) = size(raw_test);

n_labels_test = 2:N_test  
n_ids_test = 2:M_test

raw_test[n_ids_test, n_labels_test]

ids_test = raw_test[n_ids_test, 1][:]   
labels_test = raw_test[1, n_labels_test][:]
labels_test = vcat(labels_test, "Constant")

A_test = convert(Array{Float64,2}, raw_test[n_ids_test, n_labels_test])
B_test = ones(M_test-1)
data_test = hcat(A_test, B_test);

n = NamedArray(data_test, (ids_test, labels_test));

newArr = n[:, labels];

price_test = readcsv("sample_submission.csv")
price_test = price_test[:, 2]
price_test = price_test[2 : M_test]
price_test = convert(Array{Float64}, price_test);

# %% [markdown]
# ### 3.2 Regression with Least Square

# %% [markdown]
# ##### Solution: optimizing the least square cost

# %%
using JuMP, Mosek

m_ls = Model(solver=MosekSolver(LOG=0,MSK_IPAR_MAX_NUM_WARNINGS= 1))

@variable(m_ls, x[1:N])
@objective(m_ls, Min, sum( (prices - data*x).^2 ) )

solve(m_ls)

coeffs_ls = getvalue(x)
println("The value of the cost function is: ", getobjectivevalue(m_ls))
# Out:
# MOSEK warning 57: A large value of -1.0e+12 has been specified in cx for variable '' (0).
# The value of the cost function is: 1.7130703083145625e12

# %% [markdown]
# ##### Predicting values
#
# Using the coefficients from optimizint the least square cost, we predict the sale price using both the testing and training sets.

# %%
# Get predicted values
predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeffs_ls)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeffs_ls)
end

# %%
using PyPlot
scatter(predicted_test, (predicted_test - price_test), s = 2, label = "Validation Data")
scatter(predicted_train, (predicted_train - prices), s = 2, label = "Training Data")
hlines(0, 0, 600000,"k")
grid()
title("Least Square Regression")
xlabel("Predicted values")
ylabel("Residuals")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000530407F0>

# %%
using PyPlot
scatter(predicted_test, price_test, s = 2, label = "Testing Data")
scatter(predicted_train, prices, s = 2, label = "Training Data")
plot([0, 700000], [0, 700000], "k")
grid()
title("Least Square Regression")
xlabel("Predicted values")
ylabel("Real values")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000006C4E9B0>

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 68289.92244440073
# RMSE on Training Set: 34253.989951719785

# %% [markdown]
# ##### Discussion
# As we can see, by minimizing the least sqaure cost, the model we get fit to the training data pretty well. However, when we plot it against the testing data, we can see this model only works well for partial testing data. In addition, the output warning tells us that some of the coefficients are way too large. This suggests us that our model is overfitting the training data. To alleviate the impact of the overfitting, we're going to use regularization to minimize such impact.

# %% [markdown]
# ### 3.3 Least Square Regression with Different Regularizations

# %% [markdown]
# #### 3.3.1 L2 Regularization (Ridge Regression)

# %% [markdown]
# ##### Solution

# %%
using JuMP, Mosek

function solveOpt(lambda)
    m_l2 = Model(solver=MosekSolver(LOG=0, MSK_IPAR_MAX_NUM_WARNINGS=0))

    @variable(m_l2, x[1:N])
    @objective(m_l2, Min, sum( (prices - data*x).^2 ) + lambda*( sum(x.^2) ) )

    solve(m_l2)

    coeffs_l2 = getvalue(x)
    J1 = getvalue(sum((prices - data*x).^2))
    J2 = getvalue(sum(x.^2))
    return (J1, J2, coeffs_l2)
end

# %% [markdown]
# ##### Trade-off Analysis

# %%
Npts = 6
J1 = zeros(Npts)
J2 = zeros(Npts)
for (i,λ) in enumerate(logspace(-3,0,Npts))
    println("λ: " , λ)
    (J1[i], J2[i], c0oef) = solveOpt(λ)
end;
# Out:
# λ: 0.001
# λ: 0.003981071705534973
# λ: 0.015848931924611134
# λ: 0.06309573444801933
# λ: 0.251188643150958
# λ: 1.0

# %%
using PyPlot
plot(J1, J2, "b.-" )
xlabel("J1")
ylabel("J2");
title("Pareto curve for Ridge Regression")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# From the graph, we can see that when $\lambda$ is small, the value of the least square cost function is also small. It reaches at the optimum roughly at $\lambda=0.02$:

# %%
(J1, J2, coeff) = solveOpt(0.02);
println("The value of the least sqaure cost function is: ", J1)

println("\nThe coefficients are: ")
coeff_l2 = Dict( zip(labels, coeff) )
# Out:
# The value of the least sqaure cost function is: 1.7144378541281792e12
#
# The coefficients are:
# Dict{Any,Float64} with 33 entries:
#   "YearBuilt"    => 65.8442
#   "FireplaceQu"  => 1343.67
#   "GarageArea"   => 4.97465
#   "Constant"     => -398229.0
#   "CBlock.2"     => 1745.15
#   "VinylSd.1"    => 11021.2
#   "1stFlrSF"     => 32.6032
#   "GrLivArea"    => 24.6885
#   "TotRmsAbvGrd" => 2096.18
#   "BsmtFinSF1"   => 8.49143
#   "TotalBsmtSF"  => -0.25594
#   "YearRemodAdd" => 69.9489
#   "Fireplaces"   => 6565.97
#   "OpenPorchSF"  => 11.5114
#   "VinylSd"      => -11619.4
#   "FullBath"     => 2199.23
#   "PConc"        => 1531.03
#   "BsmtQual"     => 7351.74
#   "WoodDeckSF"   => 14.4299
#   "None"         => 12501.2
#   "BsmtFinType1" => 1185.67
#   "GarageType"   => 83.057
#   "GarageFinish" => 3114.79
#   "ExterQual"    => 16815.6
#   "BsmtExposure" => 6682.91
#   ⋮              => ⋮

# %%
# Get predicted values

predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeff)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeff)
end

# %%
using PyPlot
scatter(predicted_test, (predicted_test - price_test), s = 2, label = "Validation Data")
scatter(predicted_train, (predicted_train - prices), s = 2, label = "Training Data")
hlines(0, 0, 600000,"k")
grid()
title("L2 Regularization (Ridge Regression)")
xlabel("Predicted values")
ylabel("Residuals")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000530BF438>

# %%
using PyPlot
scatter(predicted_test, price_test, s = 2, label = "Testing Data")
scatter(predicted_train, prices, s = 2, label = "Training Data")
plot([0, 700000], [0, 700000], "k")
grid()
title("L2 Regularization (Ridge Regression)")
xlabel("Predicted values")
ylabel("Real values")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000530FB5F8>

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 68213.37005512869
# RMSE on Training Set: 34267.659722327604

# %% [markdown]
# ##### Discussion
# As we do not want to overly rely on the cost of the L2 regularization or the cost of least sqaure, we pick $\lambda=0.02$. Surprisingly, the overfitting is not improving much. At first we thought it may be because $\lambda$ value is too small. However, after we adjusting the values of $\lambda$ (in a reasonable range), the overfitting still was not improved much. The reason is still unclear.

# %% [markdown]
# #### 3.3.2 L1 Regularization (Lasso Regression)

# %% [markdown]
# ##### solution

# %%
using JuMP, Mosek

function solveOpt(lambda)
    m_l1 = Model(solver=MosekSolver(LOG=0, MSK_IPAR_MAX_NUM_WARNINGS=0))

    @variable(m_l1, x[1:N])
    @variable(m_l1, t[1:N])
    for i in 1:N
        @constraint(m_l1, t[i] >= x[i])
        @constraint(m_l1, t[i] >= -x[i])
    end
    @objective(m_l1, Min, sum( (prices - data*x).^2 ) + lambda*sum(t[i] for i in 1:N) )

    solve(m_l1)

    coeffs_l1 = getvalue(x)
    J1 = getvalue(sum((prices - data*x).^2))
    J2 = getvalue(sum(t[i] for i in 1:N))
    return (J1, J2, coeffs_l1)
end
# Out:
# solveOpt (generic function with 1 method)

# %% [markdown]
# ##### Trade-off Analysis

# %%
Npts = 6
J1 = zeros(Npts)
J2 = zeros(Npts)
for (i,λ) in enumerate(logspace(4,6,Npts))
    println("λ: " , λ)
    (J1[i], J2[i], coef) = solveOpt(λ)
end;
# Out:
# λ: 10000.0
# λ: 25118.864315095823
# λ: 63095.7344480193
# λ: 158489.3192461114
# λ: 398107.1705534969
# λ: 1.0e6

# %%
using PyPlot
plot(J1, J2, "b.-" )
xlabel("J1")
ylabel("J2");
title("Pareto curve for Lasso Regression")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# From the graph, we can see that when $\lambda$ is large, the value of the least square cost function remains unchanged much. It reaches at the optimum roughly at λ=63000:

# %%
(J1, J2, coeff) = solveOpt(63000);
println("The value of the least sqaure cost function is: ", J1)

println("\nThe coefficients are: ")
coeff_l1 = Dict( zip(labels, coeff) )
# Out:
# The value of the least sqaure cost function is: 1.7285724369685127e12
#
# The coefficients are:
# Dict{Any,Float64} with 33 entries:
#   "YearBuilt"    => -23.2642
#   "FireplaceQu"  => 1324.05
#   "GarageArea"   => 5.54567
#   "Constant"     => -0.242828
#   "CBlock.2"     => 3275.74
#   "VinylSd.1"    => 7507.97
#   "1stFlrSF"     => 36.9689
#   "GrLivArea"    => 20.9194
#   "TotRmsAbvGrd" => 1871.34
#   "BsmtFinSF1"   => 8.61196
#   "TotalBsmtSF"  => -1.89632
#   "YearRemodAdd" => -49.879
#   "Fireplaces"   => 6200.62
#   "OpenPorchSF"  => 12.6087
#   "VinylSd"      => -6480.62
#   "FullBath"     => 3583.21
#   "PConc"        => 4404.83
#   "BsmtQual"     => 8255.41
#   "WoodDeckSF"   => 15.8972
#   "None"         => 11567.9
#   "BsmtFinType1" => 1295.59
#   "GarageType"   => 247.784
#   "GarageFinish" => 3432.67
#   "ExterQual"    => 17609.6
#   "BsmtExposure" => 6683.07
#   ⋮              => ⋮

# %%
# Get predicted values

predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeff)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeff)
end

# %%
using PyPlot

scatter(predicted_test, (predicted_test - price_test), s = 2, label = "Validation Data")
scatter(predicted_train, (predicted_train - prices), s = 2, label = "Training Data")
hlines(0, 0, 600000,"k")
grid()
title("L1 Regularization (Lasso Regression)")
xlabel("Predicted values")
ylabel("Residuals")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000002061198>

# %%
using PyPlot
scatter(predicted_test, price_test, s = 2, label = "Testing Data")
scatter(predicted_train, prices, s = 2, label = "Training Data")
plot([0, 700000], [0, 700000], "k")
grid()
title("L1 Regularization (Lasso Regression)")
xlabel("Predicted values")
ylabel("Real values")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000002326278>

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 68118.33744686055
# RMSE on Training Set: 34408.628626251666

# %% [markdown]
# ##### Discussion
# This time we set $\lambda=63000$. Still, the overfitting is not improving much. So we try to combine L1 regularization and L2 regularization to see if it will work better.

# %% [markdown]
# #### 3.3.2 L1 and L2 Regularization

# %%
using JuMP, Mosek
function solveOpt(lambda, mu)
    m_l12 = Model(solver=MosekSolver(LOG=0, MSK_IPAR_MAX_NUM_WARNINGS=0))

    @variable(m_l12, x[1:N])
    @variable(m_l12, t[1:N])
    for i in 1:N
        @constraint(m_l12, t[i] >= x[i])
        @constraint(m_l12, t[i] >= -x[i])
    end
    @objective(m_l12, Min, sum( (prices - data*x).^2 ) + lambda*sum(x.^2) + mu*sum(t[i] for i in 1:N)  )

    solve(m_l12)

    coeffs_l1 = getvalue(x)
    J1 = getvalue(sum( (prices - data*x).^2 ))
    J2 = getvalue(sum(x.^2))
    J3 = getvalue(sum(t[i] for i in 1:N))
    
    return(J1, J2, J3, coeffs_l1)
end
# Out:
# solveOpt (generic function with 2 methods)

# %%
Npts = 8
J1 = zeros(Npts)
J2 = zeros(Npts)
J3 = zeros(Npts)
mu = logspace(4, 6, Npts)
for (i,λ) in enumerate(logspace(-3,0,Npts))
    println("λ: ", λ, " μ: ", mu[i], " ")
    (J1[i], J2[i], J3[i], coef) = solveOpt(λ, mu[i])
end;
# Out:
# λ: 0.001 μ: 10000.0
# λ: 0.0026826957952797246 μ: 19306.977288832495
# λ: 0.0071968567300115215 μ: 37275.937203149384
# λ: 0.019306977288832506 μ: 71968.56730011514
# λ: 0.0517947467923121 μ: 138949.5494373139
# λ: 0.13894954943731377 μ: 268269.57952797273
# λ: 0.372759372031494 μ: 517947.4679231213
# λ: 1.0 μ: 1.0e6

# %%
using PyPlot
plot_trisurf(J1, J2, J3)
xlabel("J1")
ylabel("J2");
zlabel("J3");
title("Pareto curve for L1 & L2 Regression")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
figure()
plot(J1, J2, "b.-")
title("Pareto Curve for J1 and J2")
grid()
figure()
plot(J1, J3, "b.-")
title("Pareto Curve for J1 and J3")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
(J1, J2, J3, coeffs) = solveOpt(0.007, 140000)
println("The value of the cost function is: ", J1+J2+J3)

println("\nThe coefficients are: ")
coeffs_l12 = Dict( zip(labels, coeffs) )
# Out:
# The value of the cost function is: 1.7344168632939316e12
#
# The coefficients are:
# Dict{Any,Float64} with 33 entries:
#   "YearBuilt"    => -19.2827
#   "FireplaceQu"  => 1423.51
#   "GarageArea"   => 6.49428
#   "Constant"     => -0.0409521
#   "CBlock.2"     => 2464.82
#   "VinylSd.1"    => 1964.84
#   "1stFlrSF"     => 37.233
#   "GrLivArea"    => 20.9444
#   "TotRmsAbvGrd" => 1844.21
#   "BsmtFinSF1"   => 8.67672
#   "TotalBsmtSF"  => -1.77653
#   "YearRemodAdd" => -53.4063
#   "Fireplaces"   => 5946.03
#   "OpenPorchSF"  => 12.9605
#   "VinylSd"      => -804.141
#   "FullBath"     => 3325.77
#   "PConc"        => 3699.9
#   "BsmtQual"     => 8311.36
#   "WoodDeckSF"   => 16.1119
#   "None"         => 11151.8
#   "BsmtFinType1" => 1298.1
#   "GarageType"   => 248.398
#   "GarageFinish" => 3358.73
#   "ExterQual"    => 17580.1
#   "BsmtExposure" => 6679.4
#   ⋮              => ⋮

# %%
# Get predicted values

predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeffs)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeffs)
end

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 68145.06416927907
# RMSE on Training Set: 34335.01648915527

# %% [markdown]
# ##### Discussion
# This time we set $\lambda=0.007$ and $\mu = 140000$.So, using least sqaure as the cost function seems not to be very ideal for this dataset. Some more robust methods are required to predict the housing prices.

# %% [markdown]
# ### 3.4 The Huber Loss

# %% [markdown]
# #### 3.4.1 Regression with the Huber Loss

# %%
using JuMP, Mosek

H = 0.18;

m_h = Model(solver=MosekSolver(LOG=0))

@variable(m_h, w[1:M-1])
@variable(m_h, v[1:M-1])
@variable(m_h, x[1:N])
for i in 1:M-1
    @constraint(m_h, w[i] <= H)
    @constraint(m_h, v[i] >= 0)
    @constraint(m_h, w[i] + v[i] >= prices[i]-sum(data[i,j]*x[j] for j in 1:N) )
    @constraint(m_h, w[i] + v[i] >= sum(data[i,j]*x[j] for j in 1:N)-prices[i] )
end
@objective(m_h, Min, sum(w.^2) + 2*M*sum(v[i] for i in 1:M-1))

solve(m_h)
coeffs_h = getvalue(x);

# %%
# Get predicted values

predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeffs_h)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeffs_h)
end

# %%
using PyPlot
scatter(predicted_test, (predicted_test - price_test), s = 2, label = "Validation Data")
scatter(predicted_train, (predicted_train - prices), s = 2, label = "Training Data")
hlines(0, 0, 700000,"k")
grid()
title("Regression with Huber Loss")
xlabel("Predicted values")
ylabel("Residuals")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000036703DA0>

# %%
using PyPlot
scatter(predicted_test, price_test, s = 2, label = "Testing Data")
scatter(predicted_train, prices, s = 2, label = "Training Data")
plot([0, 700000], [0, 700000], "k")
grid()
title("Regression with Huber Loss")
xlabel("Predicted values")
ylabel("Real values")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000003686A550>

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 64009.45802830675
# RMSE on Training Set: 35530.68829845827

# %% [markdown]
# ### 3.5 Huber Loss with Regularization

# %% [markdown]
# #### 3.5.1 Huber Loss with L2 Regularization

# %%
using JuMP, Mosek

H = 0.18;

function solveOpt(lambda)
    m_h2 = Model(solver=MosekSolver(LOG=0))

    @variable(m_h2, w[1:M-1])
    @variable(m_h2, v[1:M-1])
    @variable(m_h2, x[1:N])
    for i in 1:M-1
        @constraint(m_h2, w[i] <= H)
        @constraint(m_h2, v[i] >= 0)
        @constraint(m_h2, w[i] + v[i] >= prices[i]-sum(data[i,j]*x[j] for j in 1:N) )
        @constraint(m_h2, w[i] + v[i] >= sum(data[i,j]*x[j] for j in 1:N)-prices[i] )
    end
    @objective(m_h2, Min, sum(w.^2) + 2*H*sum(v[i] for i in 1:M-1) + lambda*sum(x.^2))

    solve(m_h2)
    coeffs_h2 = getvalue(x)
    J1 = getvalue( sum(w.^2) + 2*H*sum(v[i] for i in 1:M-1))
    J2 = getvalue(sum(x.^2))
    return(J1, J2, coeffs_h2)
end
# Out:
# solveOpt (generic function with 2 methods)

# %%
Npts = 10
J1 = zeros(Npts)
J2 = zeros(Npts)
for (i,λ) in enumerate(logspace(0,1.6,Npts))
    println("λ: ", λ)
    (J1[i], J2[i], coef) = solveOpt(λ)
end;
# Out:
# λ: 1.0
# λ: 1.5058363542798405
# λ: 2.2675431258708016
# λ: 3.414548873833602
# λ: 5.141751827683926
# λ: 7.742636826811269
# λ: 11.659144011798318
# λ: 17.556762912750013
# λ: 26.437611857491
# λ: 39.810717055349734

# %%
using PyPlot
plot(J1, J2, "b.-" )
xlabel("J1")
ylabel("J2");
title("Pareto curve for Huber Loss with L2 Regression")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
(J1, J2, coeffs) = solveOpt(5.14)
println("The value of the cost function is: ", J1)

println("\nThe coefficients are: ")
coeffs_l12 = Dict( zip(labels, coeffs) )
# Out:
# The value of the cost function is: 1.4337679542282946e7
#
# The coefficients are:
# Dict{Any,Float64} with 33 entries:
#   "YearBuilt"    => 26.752
#   "FireplaceQu"  => 13.0497
#   "GarageArea"   => 80.0839
#   "Constant"     => -0.226402
#   "CBlock.2"     => -7.03781
#   "VinylSd.1"    => 6.01268
#   "1stFlrSF"     => 50.0491
#   "GrLivArea"    => 5.95773
#   "TotRmsAbvGrd" => -2.78468
#   "BsmtFinSF1"   => 15.0169
#   "TotalBsmtSF"  => 48.8007
#   "YearRemodAdd" => -33.4652
#   "Fireplaces"   => 2.48773
#   "OpenPorchSF"  => 51.7696
#   "VinylSd"      => 5.97766
#   "FullBath"     => 4.14191
#   "PConc"        => 8.10713
#   "BsmtQual"     => 8.80078
#   "WoodDeckSF"   => 39.2364
#   "None"         => -0.646565
#   "BsmtFinType1" => 7.48067
#   "GarageType"   => 10.7276
#   "GarageFinish" => 10.2292
#   "ExterQual"    => 9.69907
#   "BsmtExposure" => 8.7774
#   ⋮              => ⋮

# %%
# Get predicted values

predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeffs)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeffs)
end

# %%
using PyPlot
scatter(predicted_test, (predicted_test - price_test), s = 2, label = "Validation Data")
scatter(predicted_train, (predicted_train - prices), s = 2, label = "Training Data")
hlines(0, 0, 700000,"k")
grid()
title("Regression with Huber Loss")
xlabel("Predicted values")
ylabel("Residuals")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000003607FF28>

# %%
using PyPlot
scatter(predicted_test, price_test, s = 2, label = "Testing Data")
scatter(predicted_train, prices, s = 2, label = "Training Data")
plot([0, 700000], [0, 700000], "k")
grid()
title("Regression with Huber Loss")
xlabel("Predicted values")
ylabel("Real values")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000360BC390>

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 59184.46396426236
# RMSE on Training Set: 44431.47702609967

# %% [markdown]
# ##### Discussion
# When we apply $\lambda=5.14$ on the the L2 regularization, we can see that by doing so, we significantly reduce the magnitude of the values of weights. As being seen in the trade-off curve, such $\lambda$ value combines huber loss and regularization well. Since the value of $\lambda$ we apply here is relatively large, the effect of such regularization is very obvious: the numbers of weights are small, but never goes down to zero, which fits what our prediction of this math model. Now let's see what will happen if we use L1 Regularization.

# %% [markdown]
# #### 3.5.2 Huber Loss with L1 Regularization

# %%
using JuMP, Mosek

H = 0.18;
function solveOpt(lambda)
    m_h1 = Model(solver=MosekSolver(LOG=0))

    @variable(m_h1, w[1:M-1])
    @variable(m_h1, v[1:M-1])
    @variable(m_h1, x[1:N])
    @variable(m_h1, t[1:N])
    for j in 1:N
        @constraint(m_h1, t[j] >= x[j])
        @constraint(m_h1, t[j] >= -x[j])
    end
    for i in 1:M-1
        @constraint(m_h1, w[i] <= H)
        @constraint(m_h1, v[i] >= 0)
        @constraint(m_h1, w[i] + v[i] >= prices[i]-sum(data[i,j]*x[j] for j in 1:N) )
        @constraint(m_h1, w[i] + v[i] >= sum(data[i,j]*x[j] for j in 1:N)-prices[i] )
    end
    @objective(m_h1, Min, sum(w.^2) + 2*H*sum(v[i] for i in 1:M-1) + lambda*sum(t[i] for i in 1:N))

    solve(m_h1)
    coeffs_h1 = getvalue(x)
    J1 = getvalue(sum(w.^2) + 2*H*sum(v[i] for i in 1:M-1))
    J2 = getvalue(sum(t[i] for i in 1:N))
    return (J1, J2, coeffs_h1)
end
# Out:
# solveOpt (generic function with 2 methods)

# %%
Npts = 9
J1 = zeros(Npts)
J2 = zeros(Npts)
for (i,λ) in enumerate(logspace(0,1.8,Npts))
    println("λ: ", λ)
    (J1[i], J2[i], coef) = solveOpt(λ)
end;
# Out:
# λ: 1.0
# λ: 1.6788040181225603
# λ: 2.8183829312644537
# λ: 4.731512589614805
# λ: 7.943282347242816
# λ: 13.33521432163324
# λ: 22.3872113856834
# λ: 37.583740428844415
# λ: 63.09573444801933

# %%
using PyPlot
plot(J1, J2, "b.-" )
xlabel("J1")
ylabel("J2");
title("Pareto curve for Huber Loss with L1 Regularization")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
(J1, J2, coeffs) = solveOpt(13)
println("The value of the cost function is: ", J1)

println("\nThe coefficients are: ")
coeffs_l12 = Dict( zip(labels, coeffs) )
# Out:
# The value of the cost function is: 1.1370102796980392e7
#
# The coefficients are:
# Dict{Any,Float64} with 33 entries:
#   "YearBuilt"    => 37.8958
#   "FireplaceQu"  => 2287.51
#   "GarageArea"   => 45.1047
#   "Constant"     => -1.43072e-8
#   "CBlock.2"     => -3.12476e-7
#   "VinylSd.1"    => 612.374
#   "1stFlrSF"     => 53.9191
#   "GrLivArea"    => 2.84742
#   "TotRmsAbvGrd" => 1.42598e-7
#   "BsmtFinSF1"   => 18.6452
#   "TotalBsmtSF"  => 19.4426
#   "YearRemodAdd" => -80.3351
#   "Fireplaces"   => 2.53439e-8
#   "OpenPorchSF"  => 30.7465
#   "VinylSd"      => 4.2739e-6
#   "FullBath"     => 2.32939e-7
#   "PConc"        => 6706.81
#   "BsmtQual"     => 2959.27
#   "WoodDeckSF"   => 20.4737
#   "None"         => 4.41537e-7
#   "BsmtFinType1" => 1.18946e-7
#   "GarageType"   => 395.754
#   "GarageFinish" => 2204.33
#   "ExterQual"    => 13111.9
#   "BsmtExposure" => 3226.01
#   ⋮              => ⋮

# %%
# Get predicted values

predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeffs)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeffs)
end

# %%
using PyPlot
scatter(predicted_test, price_test, s = 2, label = "Testing Data")
scatter(predicted_train, prices, s = 2, label = "Training Data")
plot([0, 700000], [0, 700000], "k")
grid()
title("Regression with Huber Loss with L1 Regularization")
xlabel("Predicted values")
ylabel("Real values")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000362DD550>

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 62943.91532187964
# RMSE on Training Set: 37277.32351648597

# %% [markdown]
# ##### Discussion
# By assigning $\lambda=13$, we can see the magnitudes of weights become sparse now --- also fits what we predict.

# %% [markdown]
# #### 3.5.3 Huber Loss with L1 and L2 Regularization

# %%
using JuMP, Mosek

H = 0.18;
function solveOpt(lambda, mu)
    m_h12 = Model(solver=MosekSolver(LOG=0))

    @variable(m_h12, w[1:M-1])
    @variable(m_h12, v[1:M-1])
    @variable(m_h12, x[1:N])
    @variable(m_h12, t[1:N])
    for j in 1:N
        @constraint(m_h12, t[j] >= x[j])
        @constraint(m_h12, t[j] >= -x[j])
    end
    for i in 1:M-1
        @constraint(m_h12, w[i] <= H)
        @constraint(m_h12, v[i] >= 0)
        @constraint(m_h12, w[i] + v[i] >= prices[i]-sum(data[i,j]*x[j] for j in 1:N) )
        @constraint(m_h12, w[i] + v[i] >= sum(data[i,j]*x[j] for j in 1:N)-prices[i] )
    end
    @objective(m_h12, Min, sum(w.^2) + 2*H*sum(v[i] for i in 1:M-1) + lambda*sum(x.^2) + mu*sum(t[i] for i in 1:N))

    solve(m_h12)
    coeffs_h12 = getvalue(x)
    J1 = getvalue(sum(w.^2) + 2*H*sum(v[i] for i in 1:M-1))
    J2 = getvalue(sum(x.^2))
    J3 = getvalue(sum(t[i] for i in 1:N))
    return(J1, J2, J3, coeffs_h12)
end
# Out:
# solveOpt (generic function with 2 methods)

# %%
Npts = 8
J1 = zeros(Npts)
J2 = zeros(Npts)
J3 = zeros(Npts)
mu = logspace(4, 6, Npts)
for (i,λ) in enumerate(logspace(-3,0,Npts))
    println("λ: ", λ, " mu: ", mu[i], " ")
    (J1[i], J2[i], J3[i], coef) = solveOpt(λ, mu[i])
end
# Out:
# λ: 0.001 mu: 10000.0
# λ: 0.0026826957952797246 mu: 19306.977288832495
# λ: 0.0071968567300115215 mu: 37275.937203149384
# λ: 0.019306977288832506 mu: 71968.56730011514
# λ: 0.0517947467923121 mu: 138949.5494373139
# λ: 0.13894954943731377 mu: 268269.57952797273
# λ: 0.372759372031494 mu: 517947.4679231213
# λ: 1.0 mu: 1.0e6

# %%
using PyPlot
plot_trisurf(J1, J3, J2)
xlabel("J2")
ylabel("J3");
zlabel("J1");
title("Pareto curve for Huber Loss with L1 and L2 Regularization")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
figure()
plot(J1, J2, "b.-")
title("Pareto Curve for J1 and J2")
grid()
figure()
plot(J1, J3, "b.-")
title("Pareto Curve for J1 and J3")
grid()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
(J1, J2, J3, coeffs) = solveOpt(0.14, 270000)
println("The value of the cost function is: ", J1+J2+J3)

println("\nThe coefficients are: ")
coeffs_l12 = Dict( zip(labels, coeffs) )
# Out:
# The value of the cost function is: 2.2685329837332677e7
#
# The coefficients are:
# Dict{Any,Float64} with 33 entries:
#   "YearBuilt"    => 41.3345
#   "FireplaceQu"  => 1.73482e-11
#   "GarageArea"   => 4.39741e-9
#   "Constant"     => 4.21869e-12
#   "CBlock.2"     => -1.46096e-13
#   "VinylSd.1"    => 4.13503e-12
#   "1stFlrSF"     => 1.70688e-8
#   "GrLivArea"    => 50.9879
#   "TotRmsAbvGrd" => 3.12861e-11
#   "BsmtFinSF1"   => 4.75263e-9
#   "TotalBsmtSF"  => 2.26656e-8
#   "YearRemodAdd" => 5.95141e-7
#   "Fireplaces"   => 5.70616e-12
#   "OpenPorchSF"  => 4.38464e-10
#   "VinylSd"      => 4.19246e-12
#   "FullBath"     => 9.92743e-12
#   "PConc"        => 5.6627e-12
#   "BsmtQual"     => 2.22127e-11
#   "WoodDeckSF"   => 9.36923e-10
#   "None"         => 2.05044e-14
#   "BsmtFinType1" => 2.69941e-11
#   "GarageType"   => 3.05059e-11
#   "GarageFinish" => 1.52085e-11
#   "ExterQual"    => 1.89046e-11
#   "BsmtExposure" => 1.21161e-11
#   ⋮              => ⋮

# %%
# Get predicted values

predicted_test = zeros(M_test - 1)

for i in 1: M_test - 1
    arr = newArr[i, :]
    predicted_test[i] = dot(arr, coeffs)
end

predicted_train = zeros(M - 1)

for i in 1 : M - 1
    arr = data[i, :]
    predicted_train[i] = dot(arr, coeffs)
end

# %%
using PyPlot
scatter(predicted_test, price_test, s = 2, label = "Testing Data")
scatter(predicted_train, prices, s = 2, label = "Training Data")
plot([100000, 300000], [100000, 300000], "k")
grid()
title("Regression with Huber Loss with L1 Regularization")
xlabel("Predicted values")
ylabel("Real values")
legend(loc = "upper left")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000002CB4D898>

# %%
rmse_test = rmsd(price_test, predicted_test)
rmse_train = rmsd(prices, predicted_train)

println("RMSE on Testing Set: ", rmse_test)
println("RMSE on Training Set: ", rmse_train)
# Out:
# RMSE on Testing Set: 30367.605252271085
# RMSE on Training Set: 66425.14692927847

# %% [markdown]
# ##### Discussion
# For some unknown reasons, the pareto curve for this model isn't smooth. The pareto curve between J1 and J2 is very bumpy and flattens out slightly. Before we understand the reasons behind, or are able to come up with a method to smoothing the curve out, we prefer not to use this model. It seems soly using L1 or L2 regularization works better for regression by huber loss for this dataset.

# %% [markdown]
# ## 4. Discussion ##
#
# ### 4.1 The number of labels and their correlations
# From the correlation matrx we get in "3.1 Data Preprocessing", we can see that some labels are much more closely related to the housing price than other labels. By removing all labels with r ranging from -0.3 to 0.3, the number of labels we need to deal with reduces from 170 to 33. When we try to optimize over all 170 labels, it takes the solver at least 15 minutes to run every single trial. However, when we only optimize over the 31 labels (as what we show in this project), the solver can give us the answer within 10 seconds --- signifincant improvement on speed. Here are the labels whose absolute values of correlation coefficients with housing price is larger than 0.3, suggesting these labels are somewhat important to the housing prices:

# %% [markdown]
# |Labels  | Description |
# |--------|--------------|
# |OverallQual  | Rates the overall material and finish of the house |
# |YearBuilt  | Original construction date |
# |YearRemodAdd  | Remodel date (same as construction date if no remodeling or additions) |
# |MasVnrArea  | Masonry veneer area in square feet |
# |ExterQual  | Evaluates the quality of the material on the exterior  |
# |BsmtQual  | Evaluates the height of the basement |
# |BsmtExposure  | Refers to walkout or garden level walls |
# |BsmtFinType1  | Rating of basement finished area |
# |BsmtFinSF1  | Type 1 finished square feet |
# |TotalBsmtSF  | Total square feet of basement area |
# |HeatingQC  | Heating quality and condition |
# |1stFlrSF  | First Floor square feet |
# |2ndFlrSF  | Second floor square feet |
# |GrLivArea  | Above grade (ground) living area square feet |
# |FullBath  | Full bathrooms above grade |
# |KitchenQual  | Kitchen quality |
# |TotRmsAbvGrd  | Total rooms above grade (does not include bathrooms) |
# |Fireplaces  | Number of fireplaces |
# |FireplaceQu  | Fireplace quality |
# |GarageType  | Garage location |
# |GarageFinish  | Interior finish of the garage |
# |GarageCars  | Size of garage in car capacity |
# |GarageArea  | Size of garage in square feet |
# |WoodDeckSF  | Wood deck area in square feet |
# |OpenPorchSF  | Open porch area in square feet |
# |NridgHt  | Northridge Heights |
# |VinylSd  | Exterior1st - Vinyl Siding |
# |VinylSd.1  | Exterior2nd - Vinyl Siding |
# |Stone.2  | Exterior2nd - stone |
# |PConc  | Poured Contrete  |

# %% [markdown]
# ### 4.2 The Prediction
# In this project, we tried 8 different models on the dataset: <br/>
#
# ** least square cost**
# 1. optimizing least square cost
# 2. optimizing least square with L2 Regularization
# 3. optimizing least square with L1 Regularization
# 4. optimizing least square with L1 and L2 Regularization
#
# ** the huber loss**
# 5. optimizing the huber loss
# 6. optimizing the huber loss with L1 Regularization
# 7. optimizing the huber loss with L2 Regularization
# 8. optimizing the huber loss with L1 and L2 Regularization
#
# The solutions of weights have all been presented in part 3. From the results we get in part 3, we can see that in general, the models using the huber loss as the cost function performs much better than the models using the least sqaure as the cost function: While errors for model 1-4 are around 1.6e12, the error for model 5-8 are around 1.4e7, which differs on a 100,000 times scale. The residual graph in part 3 also implies that the model given by the least sqaure cost can give us accurate prediction for parts of the data. On the other hand, if we look at the ideal values of $\lambda$, the ones for model 5-7 (the $\lambda$ value for model 8 is abnormal so we do not include it in our discussion here) are much more reasonable than those for model 1-4.  This outcomes fits to our prediction, as the huber loss automatically minimize the impact of the outliers and makes the model more robust.

# %% [markdown]
# ### 4.3 Limitation and  Future Improvement
# One of the biggest problems in this project is how to reduce overfitting. As we can see, regularizations seem not to work very well for this dataset surprisingly. One possible solution would be further reducing the amount of labels. Instead of setting $r=0.3$, we can raise it to $r=0.4$ or even higher. Another potential fix would be when preprocessing data, we may want to normalize them first. As when we convert all the discrete variables into numerical ones, we only assign 1 and 0 to these labels. Compared with the other numerical variabls, 0 and 1 are much smaller in value. If such labels are important, we will unavoidably need to assign larger weight values to them, which might lead to overfitting.

# %% [markdown]
# ## 5. Conclusion ##

# %% [markdown]
# #### Root mean square errors of different regression and regularization technique
#
# |Regression Type|Test Data| Train Data  |
# |---------------|---------|-------------|
# |Least Square   |68289    |34253        |
# |Least Square with L2 Regularization|68213    |34267       |
# |Least Square with L1 Regularization|68118    |34408        |
# |Least Square with L1 and L2 Regularization |68145    |34335        |
# |Huber Loss   |64009    |35530        |
# |Huber Loss with L1 Regularization  |59184    |44431        |
# |Huber Loss with L2 Regularization  |62943    |37277        |
# |Huber Loss with L1 and L2 Regularization  |30367    |66425        |
#
#
# To improve on our results, we could work on data preprocessing. Instead of filling up missing values with 0 as we did in this project, we could fill them with the mean value, the most common value or the median. We could also combine or simplify existing features to reduce the number of features. We could also experiment with cutoff points for correlation values. To help with outliers, we could log transform skewed features to lessen the impact of outliers.

# %% [markdown]
# ## 6. Appendix

# %%
function sqL2dist(a::AbstractArray{T}, b::AbstractArray{T}) where T<:Number
    n = length(a)
    length(b) == n || throw(DimensionMismatch("Input dimension mismatch"))
    r = 0.0
    for i = 1:n
        @inbounds r += abs2(a[i] - b[i])
    end
    return r
end

function rmsd(a::AbstractArray{T}, b::AbstractArray{T}; normalize::Bool=false) where T<:Number
    v = sqrt(sqL2dist(a, b) / length(a))
    if normalize
        amin, amax = extrema(a)
        v /= (amax - amin)
    end
    return v
end
# Out:
# rmsd (generic function with 1 method)
